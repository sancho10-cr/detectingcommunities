# %%
# !pip install networkx matplotlib scipy numpy sklearn python-louvain

# %%
import networkx as nx
import matplotlib.pyplot as plt
from community import community_louvain
from scipy.io import mmread


# Load the American College football network dataset
#G = nx.read_gml('inputs/football/football.gml')

#load the zachary'karate dataset
#G = nx.karate_club_graph()

# Load the Bottlenose Dolphins network dataset
#G = nx.read_gml('inputs/dolphins/dolphins.gml')

# Load the Books about US politics networks dataset
#G = nx.read_gml('inputs/polbooks/polbooks.gml')

# Load the US power grid network
#G = nx.read_gml('inputs/power/power.gml', label = 'id')

# Load the MTX file: Email, the university network as a sparse adjacency matrix
adj_matrix = mmread("inputs/email/email.mtx").tocsr()

# Convert the sparse adjacency matrix to a NetworkX graph
G = nx.from_scipy_sparse_matrix(adj_matrix)

# Print some information about the graph
print(nx.info(G))

# Compute the communities using the Louvain algorithm
partition = community_louvain.best_partition(G)

# Draw the  network with nodes colored by their community
pos = nx.spring_layout(G)
cmap = plt.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=50, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()
# Out:
# C:\Users\zambogo\AppData\Local\Temp\ipykernel_15688\2608574461.py:26: DeprecationWarning:
#
# The scipy.sparse array containers will be used instead of matrices
# in Networkx 3.0. Use `from_scipy_sparse_array` instead.
#   G = nx.from_scipy_sparse_matrix(adj_matrix)
# C:\Users\zambogo\AppData\Local\Temp\ipykernel_15688\2608574461.py:29: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(G))
# Graph with 1133 nodes and 5451 edges

# %%
import networkx as nx
import community

# Load the American College football network dataset
G = nx.read_gml('inputs/football/football.gml')

#load the zachary'karate dataset
#G = nx.karate_club_graph()

# Load the Bottlenose Dolphins network dataset
#G = nx.read_gml('inputs/dolphins/dolphins.gml')

# Load the Books about US politics networks dataset
#G = nx.read_gml('inputs/polbooks/polbooks.gml')

# Load the US power grid network
#G = nx.read_gml('inputs/power/power.gml', label = 'id')

# Load the MTX file: Email, the university network as a sparse adjacency matrix
#adj_matrix = mmread("inputs/email/email.mtx").tocsr()

# Convert the sparse adjacency matrix to a NetworkX graph
#G = nx.from_scipy_sparse_matrix(adj_matrix)

# Print some information about the graph
print(nx.info(G))

# Run the Louvain algorithm to detect communities
partition = community.best_partition(G)

# Print the number of communities detected
print('Number of communities: {}'.format(len(set(partition.values()))))

# Print the nodes in each community
for i in set(partition.values()):
    nodes = [nodes for nodes in partition.keys() if partition[nodes] == i]
    print('Community {}: {}'.format(i, nodes))
# Out:
# Graph with 115 nodes and 613 edges
# Number of communities: 10
# Community 0: ['BrighamYoung', 'NewMexico', 'SanDiegoState', 'NorthTexas', 'Wyoming', 'Utah', 'ArkansasState', 'BoiseState', 'ColoradoState', 'Idaho', 'NewMexicoState', 'UtahState', 'AirForce', 'NevadaLasVegas']
# Community 1: ['FloridaState', 'NorthCarolinaState', 'Virginia', 'GeorgiaTech', 'Duke', 'NorthCarolina', 'Clemson', 'WakeForest', 'Maryland']
# Community 2: ['Iowa', 'PennState', 'Northwestern', 'Wisconsin', 'Michigan', 'Purdue', 'OhioState', 'Minnesota', 'Illinois', 'MichiganState', 'Indiana']
# Community 3: ['KansasState', 'TexasTech', 'Baylor', 'Colorado', 'Kansas', 'IowaState', 'Nebraska', 'TexasA&M', 'Oklahoma', 'Texas', 'Missouri', 'OklahomaState']
# Community 4: ['Auburn', 'Alabama', 'Florida', 'CentralFlorida', 'Kentucky', 'LouisianaTech', 'LouisianaMonroe', 'Vanderbilt', 'MiddleTennesseeState', 'MississippiState', 'SouthCarolina', 'Tennessee', 'Mississippi', 'Georgia', 'LouisianaState', 'LouisianaLafayette', 'Arkansas']
# Community 5: ['SouthernCalifornia', 'ArizonaState', 'UCLA', 'Arizona', 'Washington', 'Oregon', 'Stanford', 'WashingtonState', 'OregonState', 'California']
# Community 6: ['EastCarolina', 'Houston', 'Louisville', 'Memphis', 'SouthernMississippi', 'Tulane', 'Army', 'Cincinnati', 'AlabamaBirmingham']
# Community 7: ['FresnoState', 'Rice', 'SouthernMethodist', 'Nevada', 'SanJoseState', 'TexasElPaso', 'Tulsa', 'TexasChristian', 'Hawaii']
# Community 8: ['VirginiaTech', 'BostonCollege', 'WestVirginia', 'Syracuse', 'Pittsburgh', 'Temple', 'Navy', 'NotreDame', 'Rutgers', 'MiamiFlorida']
# Community 9: ['NorthernIllinois', 'WesternMichigan', 'Akron', 'BallState', 'BowlingGreenState', 'Buffalo', 'CentralMichigan', 'Connecticut', 'EasternMichigan', 'Kent', 'MiamiOhio', 'Ohio', 'Toledo', 'Marshall']
# C:\Users\zambogo\AppData\Local\Temp\ipykernel_15688\3108108003.py:26: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(G))

# %%
import community
import networkx as nx
import random

# Load the American football network
G = nx.read_gml('inputs/karate/karate.gml', label = 'id')

# Define the fitness function
def fitness(partition, G):
    partition_labels = {label: partition[i] for i, label in enumerate(G.nodes)}
    return community.modularity(partition_labels, G)

# Define the genetic algorithm parameters
POPULATION_SIZE = 100
CROSSOVER_PROBABILITY = 0.9
MUTATION_PROBABILITY = 0.2
NUM_ITERATIONS = 10000

# Initialize the population with random community structures
population = []
for _ in range(POPULATION_SIZE):
    partition = [random.randint(0, POPULATION_SIZE-1) for _ in range(G.number_of_nodes())]
    population.append(partition)

# Evaluate the fitness of the initial population
fitness_scores = [fitness(p, G) for p in population]

# Perform elitism for the specified number of iterations
for i in range(NUM_ITERATIONS):
    # Select the top 10% of the population to carry over to the next generation
    num_elites = int(POPULATION_SIZE * 0.1)
    elites = [population[idx] for idx in sorted(range(POPULATION_SIZE), key=lambda x: fitness_scores[x], reverse=True)[:num_elites]]

    # Create the next generation of the population using tournament selection, crossover, and mutation
    new_population = []
    for _ in range(POPULATION_SIZE - num_elites):
        # Perform tournament selection to select two parents
        tournament_size = 5
        tournament = random.sample(range(POPULATION_SIZE), tournament_size)
        parent1 = population[tournament[0]]
        for idx in tournament[1:]:
            if fitness_scores[idx] > fitness_scores[tournament[0]]:
                parent1 = population[idx]
        tournament = random.sample(range(POPULATION_SIZE), tournament_size)
        parent2 = population[tournament[0]]
        for idx in tournament[1:]:
            if fitness_scores[idx] > fitness_scores[tournament[0]]:
                parent2 = population[idx]

        # Perform crossover with probability CROSSOVER_PROBABILITY
        if random.random() < CROSSOVER_PROBABILITY:
            crossover_point = random.randint(0, G.number_of_nodes()-1)
            child1 = parent1[:crossover_point] + parent2[crossover_point:]
            child2 = parent2[:crossover_point] + parent1[crossover_point:]
        else:
            child1, child2 = parent1, parent2

        # Perform mutation with probability MUTATION_PROBABILITY
        if random.random() < MUTATION_PROBABILITY:
            mutation_point = random.randint(0, G.number_of_nodes()-1)
            child1[mutation_point] = random.randint(0, POPULATION_SIZE-1)
        if random.random() < MUTATION_PROBABILITY:
            mutation_point = random.randint(0, G.number_of_nodes()-1)
            child2[mutation_point] = random.randint(0, POPULATION_SIZE-1)

        new_population.extend([child1, child2])

    # Combine the elites and the new population to form the next generation
    population = elites + new_population

    # Evaluate the fitness of the new population
    fitness_scores = [fitness(p, G) for p in population]

    # Print the best modularity value found so far
    print(f"Iteration {i+1}: Best modularity = {max(fitness_scores):.4f}")
# Out:
# Iteration 1: Best modularity = -0.0173
# Iteration 2: Best modularity = -0.0108
# Iteration 3: Best modularity = -0.0077
# Iteration 4: Best modularity = 0.0031
# Iteration 5: Best modularity = 0.0031
# Iteration 6: Best modularity = 0.0118
# Iteration 7: Best modularity = 0.0230
# Iteration 8: Best modularity = 0.0230
# Iteration 9: Best modularity = 0.0311
# Iteration 10: Best modularity = 0.0245
# Iteration 11: Best modularity = 0.0330
# Iteration 12: Best modularity = 0.0344
# Iteration 13: Best modularity = 0.0543
# Iteration 14: Best modularity = 0.0604
# Iteration 15: Best modularity = 0.0557
# Iteration 16: Best modularity = 0.0604
# Iteration 17: Best modularity = 0.0717
# Iteration 18: Best modularity = 0.0717
# Iteration 19: Best modularity = 0.0952
# Iteration 20: Best modularity = 0.0952
# Iteration 21: Best modularity = 0.0962
# Iteration 22: Best modularity = 0.1049
# Iteration 23: Best modularity = 0.1049
# Iteration 24: Best modularity = 0.1059
# Iteration 25: Best modularity = 0.1059
# Iteration 26: Best modularity = 0.1059
# Iteration 27: Best modularity = 0.1258
# Iteration 28: Best modularity = 0.1154
# Iteration 29: Best modularity = 0.1072
# Iteration 30: Best modularity = 0.1072
# Iteration 31: Best modularity = 0.1072
# Iteration 32: Best modularity = 0.1165
# Iteration 33: Best modularity = 0.1155
# Iteration 34: Best modularity = 0.1072
# Iteration 35: Best modularity = 0.1072
# Iteration 36: Best modularity = 0.1072
# Iteration 37: Best modularity = 0.1072
# Iteration 38: Best modularity = 0.1072
# Iteration 39: Best modularity = 0.1072
# Iteration 40: Best modularity = 0.1165
# Iteration 41: Best modularity = 0.1072
# Iteration 42: Best modularity = 0.1160
# Iteration 43: Best modularity = 0.1160
# Iteration 44: Best modularity = 0.1387
# Iteration 45: Best modularity = 0.1476
# Iteration 46: Best modularity = 0.1476
# Iteration 4915: Best modularity = 0.3853
# Iteration 4916: Best modularity = 0.3853
# Iteration 4917: Best modularity = 0.3853
# Iteration 4918: Best modularity = 0.3853
# Iteration 4919: Best modularity = 0.3853
# Iteration 4920: Best modularity = 0.3853
# Iteration 4921: Best modularity = 0.3853
# Iteration 4922: Best modularity = 0.3853
# Iteration 4923: Best modularity = 0.3853
# Iteration 4924: Best modularity = 0.3853
# Iteration 4925: Best modularity = 0.3853
# Iteration 4926: Best modularity = 0.3853
# Iteration 4927: Best modularity = 0.3853
# Iteration 4928: Best modularity = 0.3853
# Iteration 4929: Best modularity = 0.3853
# Iteration 4930: Best modularity = 0.3853
# Iteration 4931: Best modularity = 0.3853
# Iteration 4932: Best modularity = 0.3853
# Iteration 4933: Best modularity = 0.3853
# Iteration 4934: Best modularity = 0.3853
# Iteration 4935: Best modularity = 0.3853
# Iteration 4936: Best modularity = 0.3853
# Iteration 4937: Best modularity = 0.3853
# Iteration 4938: Best modularity = 0.3853
# Iteration 4939: Best modularity = 0.3853
# Iteration 4940: Best modularity = 0.3853
# Iteration 4941: Best modularity = 0.3853
# Iteration 4942: Best modularity = 0.3853
# Iteration 4943: Best modularity = 0.3853
# Iteration 4944: Best modularity = 0.3853
# Iteration 4945: Best modularity = 0.3853
# Iteration 4946: Best modularity = 0.3853
# Iteration 4947: Best modularity = 0.3853
# Iteration 4948: Best modularity = 0.3853
# Iteration 4949: Best modularity = 0.3853
# Iteration 4950: Best modularity = 0.3853
# Iteration 4951: Best modularity = 0.3853
# Iteration 4952: Best modularity = 0.3853
# Iteration 4953: Best modularity = 0.3853
# Iteration 4954: Best modularity = 0.3853
# Iteration 4955: Best modularity = 0.3853
# Iteration 4956: Best modularity = 0.3853
# Iteration 4957: Best modularity = 0.3853
# Iteration 4958: Best modularity = 0.3853
# Iteration 4959: Best modularity = 0.3853
# Iteration 4960: Best modularity = 0.3853
# Iteration 4961: Best modularity = 0.3853
# Iteration 4962: Best modularity = 0.3853
# Iteration 4963: Best modularity = 0.3853
# Iteration 4964: Best modularity = 0.3853
# Iteration 4965: Best modularity = 0.3853

# %%
pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 2.4 MB/s eta 0:00:00
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\zambogo\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Installing collected packages: joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
from networkx.algorithms.community import greedy_modularity_communities

# Load the American football network
G = nx.read_gml('inputs/football/football.gml')

# Get the communities using the greedy modularity algorithm
communities = list(greedy_modularity_communities(G))

# Calculate the modularity value
modularity = nx.algorithms.community.modularity(G, communities)

print("Modularity value of American football network:", modularity)
# Out:
# Modularity value of American football network: 0.5564043335134086

# %%
import networkx as nx
import community
from scipy.io import mmread

# Load the American College football network dataset
#G = nx.read_gml('inputs/football/football.gml')

#load the zachary'karate dataset
#G = nx.karate_club_graph()

# Load the Bottlenose Dolphins network dataset
#G = nx.read_gml('inputs/dolphins/dolphins.gml')

# Load the Books about US politics networks dataset
#G = nx.read_gml('inputs/polbooks/polbooks.gml')

# Load the US power grid network
#G = nx.read_gml('inputs/power/power.gml', label = 'id')

# Load the MTX file: Email, the university network as a sparse adjacency matrix
adj_matrix = mmread("inputs/email/email.mtx").tocsr()

# Convert the sparse adjacency matrix to a NetworkX graph
G = nx.from_scipy_sparse_matrix(adj_matrix)

# calculate the modularity value using the Louvain algorithm optimised with elitism
partition = community.best_partition(G)
modularity = community.modularity(partition, G)

# print the modularity value
print("Modularity value of network using Louvain algorithm optimised with elitism: ", modularity)
# Out:
# C:\Users\zambogo\AppData\Local\Temp\ipykernel_15688\2213534858.py:24: DeprecationWarning:
#
# The scipy.sparse array containers will be used instead of matrices
# in Networkx 3.0. Use `from_scipy_sparse_array` instead.
#   G = nx.from_scipy_sparse_matrix(adj_matrix)
# Modularity value of network using Louvain algorithm optimised with elitism:  0.55603436308082

# %%
import numpy as np
import networkx as nx
from sklearn import metrics
import community
from scipy.io import mmread


# Load the football network from the GML file
G = nx.read_gml('inputs/football/football.gml', label='id')

# Apply the Louvain algorithm to cluster the nodes
partition = community.best_partition(G)

# Convert the partition dictionary to a numpy array
y_pred = np.array(list(partition.values()))

# Load the true labels of the nodes from the graph
y_true = np.array([G.nodes[node]['value'] for node in G])

# Evaluate using Normalized Mutual Information
nmi = metrics.normalized_mutual_info_score(y_true, y_pred)
print("Normalized Mutual Information:", nmi)

# Evaluate using Adjusted Rand Index
ari = metrics.adjusted_rand_score(y_true, y_pred)
print("Adjusted Rand Index:", ari)

# Evaluate using F1 score
fscore = metrics.f1_score(y_true, y_pred, average='weighted')
print("F1 Score:", fscore)

# Evaluate using Conductance
adjacency_matrix = nx.to_numpy_array(G)

S = np.where(y_pred == 0)[0]
T = np.where(y_pred != 0)[0]

if len(S) == 0 or len(T) == 0:
    conductance = 0
else:
    conductance = nx.algorithms.cuts.conductance(G, S, T)

print("Conductance:", conductance)
# Out:
# Normalized Mutual Information: 0.8903166312052428
# Adjusted Rand Index: 0.8069408992735126
# F1 Score: 0.30496894409937886
# Conductance: 0.3424657534246575

# %%
import networkx as nx
import community
import matplotlib.pyplot as plt

# Load the American College football network dataset
G = nx.read_gml('../inputs/football/football.gml')

# Run the Louvain algorithm to detect communities
partition = community.best_partition(G)

# Get the number of communities detected
num_communities = len(set(partition.values()))

# Create a dictionary to store community members
communities = {}
for i in range(num_communities):
    communities[i] = []

# Populate the dictionary with community members
for node, community_id in partition.items():
    communities[community_id].append(node)

# Determine the maximum number of members in any community
max_members = max(len(members) for members in communities.values())

# Create the table data with equal number of columns for each row
table_data = []
for i in range(num_communities):
    community_nodes = communities[i]
    community_nodes.extend([''] * (max_members - len(community_nodes)))  # Add empty cells for padding
    table_data.append(['Community {}'.format(i)] + community_nodes)

# Plot the table
fig, ax = plt.subplots(figsize=(10, 6))
table = ax.table(cellText=table_data, cellLoc='center', loc='center')

# Set table properties
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.5)

# Remove axis
ax.axis("off")

# Set title
ax.set_title("Communities in the Network")

# Show the table
plt.show()
